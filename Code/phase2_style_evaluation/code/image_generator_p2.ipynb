# %%
import json

# Load and examine the structure of the file
with open('refined_prompts.json', 'r') as f:
    data = json.load(f)
    
# Look at first sample structure
print("\nFirst sample structure:")
print(json.dumps(data[0], indent=2))

# Show some basic stats
print(f"\nTotal number of samples: {len(data)}")
print(f"Number of prompts in first sample: {len(data[0]['template_prompts'])}")
# Out:
# First sample structure:
# {
#   "index": 71,
#   "id": "wikipedia_387",
#   "simplified_text": "Originally, a pie made with any kind of meat and mashed potato was called a cottage pie ''.",
#   "dataset_source": "Wikipedia",
#   "template_prompts": [
#     {
#       "style": "Cartoon",
#       "prompt": "Image generation prompt:\n\nGenerate a cartoon-style image with a light gray, solid-colored background. The image should include the following four objects, arranged in a linear, easily scannable pattern from left to right, with each object scaled to a similar size and a minimum of 30% spacing between each object:\n\n1. A whole, uncooked piece of meat (such as a steak or a chicken drumstick).\n2. A knife and a fork, indicating the meat is ready to be cut and cooked.\n3. A bowl of raw, unpeeled potatoes.\n4. A freshly baked pie with a golden-brown crust, slightly steaming to indicate it is hot out of the oven.\n\nEnsure that each object is depicted in a simple form with clear outlines and flat colors, with maximum contrast between each object. Avoid any shadows or lighting effects, and keep object details clear but minimal to ensure cognitive accessibility.",
#       "template_name": "Basic Object Focus (Refined)"
#     },
#     {
#       "style": "Realistic",
#       "prompt": "Prompt: \n\n\"Create a realistic image with a light gray background, showcasing four distinct objects: \n\n1. A piece of raw meat (like a steak or chicken breast) symbolizing 'any kind of meat'\n2. A fresh, whole potato, representing 'mashed potato'\n3. An empty pie tin, to symbolize 'pie'\n4. A small, simple cottage to represent 'cottage pie'\n\nEnsure that the objects are arranged in a simple, scannable pattern from left to right. Each object should be similar in size (with a maximum of 10% variation), have clear but minimal details and be separated by at least 30% of the image width. Try to maximize the contrast between the objects and the background. Avoid any shadows or lighting effects that may lead to confusion. Make sure every object is easily recognizable and relatable to real-world objects.\"",
#       "template_name": "Basic Object Focus (Refined)"
#     },
#     {
#       "style": "Artistic",
#       "prompt": "Prompt:\n\nProduce an image in an Artistic style featuring the following elements in a clear and simple layout against a light-gray background:\n1. A classic pie dish: It should be round in shape, preferably in a contrasting color to the background.\n2. Mashed potatoes: in a separate bowl, stylized but recognizable.\n3. Meat: Show a distinct piece of meat (like a steak or roast), not cooked, to represent any kind of meat.\n4. A completed cottage pie: It should be in another pie dish, but this time with the mashed potatoes visibly layered on top of the meat, representing the final product. \n\nEnsure there is a minimum of 30% spacing between each object and no overlap. Use visual cues such as color and shape to distinguish between the different objects. Avoid any shadows or lighting effects to keep the image clear and easy to understand.",
#       "template_name": "Basic Object Focus (Refined)"
#     },
#     {
#       "style": "Minimalistic",
#       "prompt": "Prompt: \"Generate an image with a light gray background. Place four distinct objects on this background: A pie dish, raw minced meat, mashed potatoes, and a cottage house. The objects should be arranged in an easily scannable pattern with maximum contrast between them. Ensure that there is at least 30% minimum spacing between these objects. The pie dish should be empty, the minced meat should be uncooked and the mashed potato should look ready to eat. Each object should be scaled to similar sizes with no more than 10% variation. Avoid any shadows or lighting effects that could cause confusion, and keep object details clear but minimal.\"",
#       "template_name": "Basic Object Focus (Refined)"
#     },
#     {
#       "style": "Digital Art",
#       "prompt": "Prompt:\nCreate a digital art image consisting of four distinct objects: a pie, a piece of meat, a potato, and a simple cottage. Arrange these objects on a light gray background with a minimum of 30% spacing between them. The pie should appear to be made with the meat and mashed potato, but these components should be clearly distinct. The cottage should be simple in design with clear but minimal detail. There should be a strong contrast between all objects. The objects should be scaled to similar sizes, with no more than a 10% variation in size. Avoid any shadows or lighting effects that might cause confusion. The image should be clean and sharp, maintaining the style characteristics of digital art.",
#       "template_name": "Basic Object Focus (Refined)"
#     },
#     {
#       "style": "3D Rendered",
#       "prompt": "Prompt: \n\nGenerate an image in a 3D rendered style on a neutral light-grey background. The image should contain four distinct objects: \n\n1. A plate with a pie made out of meat. The pie should be whole and not cut. \n\n2. A pile of raw ground meat next to the pie to represent the filling. \n\n3. A pile of mashed potatoes, distinguishable from the other objects, to represent the topping of the pie. \n\n4. A small, quaint cottage to represent the term 'cottage pie'. \n\nEnsure a minimum 30% spacing between objects, maintain high contrast between the objects, and keep the object details clear but minimal. Avoid any shadows or lighting effects. Objects should be arranged in an easily scannable pattern, with sizes within a 10% variation.",
#       "template_name": "Basic Object Focus (Refined)"
#     },
#     {
#       "style": "Geometric",
#       "prompt": "Image Generation Prompt:\n\nGenerate a geometric style image composed of four distinct objects: a circular pie, a slice of pie, a piece of meat, and a mashed potato. \n\n1) Pie: Draw a large circle filled with a pattern that signifies a pie. Keep the details minimal.\n\n2) Slice of Pie: Draw a triangular shape beside the pie representing a slice of pie. The slice should be filled with the same pattern as the pie.\n\n3) Meat: Draw a chunk of meat using simple geometric shapes, maintaining the color and texture distinct from the pie.\n\n4) Mashed Potato: Draw mashed potato using simple shapes and a color distinct from the other objects. \n\nArrange these objects on a flat, solid-colored light gray background. Ensure that each object is separated by a minimum of 30% spacing. All objects should be similar in size and easy to identify. Avoid shadows or lighting effects to prevent any confusion. Ensure maximum contrast between the objects.",
#       "template_name": "Basic Object Focus (Refined)"
#     },
#     {
#       "style": "Retro",
#       "prompt": "Prompt: \n\nGenerate an image in a Retro style that depicts the following scene: \n\n1. A whole pie with a distinguishable crust on a light gray background. The pie should be depicted in a simple, stylized way with a clear boundary. \n\n2. A bowl filled with mashed potatoes next to the pie. The bowl and mashed potatoes should be easily distinguishable from each other and the background. \n\n3. On the other side of the pie, place a piece of raw meat, depicted in a stylized manner that's consistent with the Retro style. \n\n4. A small vintage cottage should be included in the scene as a representative of the term \"cottage pie\". \n\nEnsure that all objects are scaled to similar sizes, with a 30% minimum space between them for clarity. All objects should have clear but minimal details, with maximum contrast to the background. Avoid any shadows or lighting effects that may cause confusion.",
#       "template_name": "Basic Object Focus (Refined)"
#     },
#     {
#       "style": "Storybook",
#       "prompt": "Prompt:\n\"Generate an image in a Storybook style on a solid light grey background. The picture should include four distinct objects: a whole uncooked pie, a separate piece of uncooked meat, a pile of mashed potatoes, and a small cottage. Each object should be scaled to a similar size with a 10% variation allowance. Place them in an easily scannable pattern with a minimum of 30% spacing between each. Ensure objects have maximum contrast against the background with clear but minimal detailing. No shadows or lighting effects should be used.\"",
#       "template_name": "Basic Object Focus (Refined)"
#     },
#     {
#       "style": "Technical",
#       "prompt": "Prompt:\n\"Create an image on a light gray background. The image should contain four distinct objects: a pie dish, a piece of meat, a potato, and a mashed potato. Position each object with at least 30% space from one another in a square pattern for easy scanning. The objects should be similar in size, with a maximum 10% size variation. Draw each object with precise linework and clear, minimal details. Ensure maximum contrast between the objects and the background. Avoid shadows or lighting effects that may create confusion.\"",
#       "template_name": "Basic Object Focus (Refined)"
#     }
#   ]
# }
#
# Total number of samples: 400
# Number of prompts in first sample: 10

# %%
import json 
import os
import time
import asyncio
import aiohttp
from typing import List, Dict, Optional
from openai import OpenAI
from rich.console import Console
from rich.progress import Progress, SpinnerColumn, TimeElapsedColumn
from datetime import datetime

class ProcessingStats:
    """Helper class to track processing statistics"""
    def __init__(self):
        self.start_time = datetime.now()
        self.total_attempts = 0
        self.successful_downloads = 0
        self.failed_downloads = 0
        self.rate_limit_hits = 0
        self.connection_errors = 0
        
    def get_summary(self) -> Dict:
        """Get processing statistics summary"""
        duration = datetime.now() - self.start_time
        return {
            "duration": str(duration),
            "total_attempts": self.total_attempts,
            "successful_downloads": self.successful_downloads,
            "failed_downloads": self.failed_downloads,
            "rate_limit_hits": self.rate_limit_hits,
            "connection_errors": self.connection_errors,
            "success_rate": f"{(self.successful_downloads / self.total_attempts * 100):.2f}%" if self.total_attempts > 0 else "0%"
        }

class ProcessingControl:
    """Helper class to control processing flow"""
    def __init__(self):
        self.pause_flag = False
        self.stop_flag = False
        
    def pause(self):
        """Pause processing after current chunk"""
        self.pause_flag = True
        
    def resume(self):
        """Resume processing"""
        self.pause_flag = False
        
    def stop(self):
        """Stop processing after current chunk"""
        self.stop_flag = True
        
    def reset(self):
        """Reset control flags"""
        self.pause_flag = False
        self.stop_flag = False

class RobustImageGenerator:
    def __init__(self, api_key: str):
        self.console = Console()
        self.client = OpenAI(api_key=api_key)
        # Updated paths
        self.input_path = os.path.join(os.getcwd(), 'refined_prompts.json')
        self.base_output_path = os.path.join(os.path.dirname(os.getcwd()), 'images')
        self.state_file = os.path.join(os.getcwd(), 'generation_state.json')
        self.max_retries = 3
        self.retry_delay = 5  # seconds
        self.stats = ProcessingStats()
        self.control = ProcessingControl()
        
    def load_state(self) -> Dict:
        """Load processing state from file."""
        if os.path.exists(self.state_file):
            try:
                with open(self.state_file, 'r') as f:
                    return json.load(f)
            except json.JSONDecodeError:
                self.console.print("[yellow]Warning: Corrupted state file, starting fresh")
        return {
            'completed_samples': [],
            'failed_samples': [],
            'last_chunk_index': 0,
            'timestamp': datetime.now().isoformat()
        }
    
    def save_state(self, state: Dict):
        """Save processing state to file."""
        with open(self.state_file, 'w') as f:
            json.dump(state, f, indent=2)

    async def download_image_with_retry(self, 
                                      session: aiohttp.ClientSession, 
                                      url: str, 
                                      filepath: str) -> bool:
        """Download image with retry mechanism."""
        self.stats.total_attempts += 1
        
        for attempt in range(self.max_retries):
            try:
                async with session.get(url) as response:
                    if response.status == 200:
                        os.makedirs(os.path.dirname(filepath), exist_ok=True)
                        with open(filepath, 'wb') as f:
                            f.write(await response.read())
                        self.stats.successful_downloads += 1
                        return True
                    elif response.status == 429:  # Rate limit
                        self.stats.rate_limit_hits += 1
                        wait_time = (attempt + 1) * self.retry_delay
                        self.console.print(f"[yellow]Rate limited, waiting {wait_time}s...")
                        await asyncio.sleep(wait_time)
                    else:
                        self.console.print(f"[red]Download failed: {response.status}")
                        await asyncio.sleep(self.retry_delay)
            except Exception as e:
                self.stats.connection_errors += 1
                if attempt < self.max_retries - 1:
                    wait_time = (attempt + 1) * self.retry_delay
                    self.console.print(f"[yellow]Retry {attempt + 1}/{self.max_retries} after error: {str(e)}")
                    await asyncio.sleep(wait_time)
                else:
                    self.console.print(f"[red]Final download attempt failed: {str(e)}")
                    self.stats.failed_downloads += 1
                    return False
        
        self.stats.failed_downloads += 1
        return False

    async def generate_single_image(self, 
                                  session: aiohttp.ClientSession,
                                  sample: Dict,
                                  template_prompt: Dict,
                                  semaphore: asyncio.Semaphore) -> Dict:
        """Generate a single image with detailed status tracking."""
        result = {
            'sample_id': sample['id'],
            'dataset': sample['dataset_source'].lower(),
            'style': template_prompt['style'].lower(),
            'success': False,
            'error': None,
            'timestamp': datetime.now().isoformat()
        }
        
        try:
            async with semaphore:
                # Generate image with DALL-E 3
                response = await asyncio.get_event_loop().run_in_executor(
                    None,
                    lambda: self.client.images.generate(
                        model="dall-e-3",
                        prompt=template_prompt['prompt'],
                        size="1024x1024",
                        quality="hd",  # Changed to HD for full quality
                        n=1
                    )
                )
                
                image_url = response.data[0].url
                
                # Create filenames with new naming convention
                filename = f"{result['dataset']}_{sample['id']}_{result['style']}.png"
                
                # Define paths for both organizations
                paths = [
                    os.path.join(self.base_output_path, 'by_style', 
                               result['style'], filename),
                    os.path.join(self.base_output_path, 'by_dataset',
                               result['dataset'], filename)
                ]
                
                # Download to both locations
                successes = await asyncio.gather(
                    *[self.download_image_with_retry(session, image_url, path) 
                      for path in paths]
                )
                
                result['success'] = all(successes)
                if not result['success']:
                    result['error'] = "Failed to download to all locations"
                
        except Exception as e:
            result['error'] = str(e)
            self.console.print(f"[red]Error processing {result['sample_id']}, {result['style']}: {str(e)}")
        
        return result

    async def process_chunk(self, 
                          samples: List[Dict], 
                          start_idx: int,
                          chunk_size: int,
                          state: Dict,
                          semaphore: asyncio.Semaphore) -> Dict:
        """Process a chunk of samples with state tracking."""
        end_idx = min(start_idx + chunk_size, len(samples))
        chunk = samples[start_idx:end_idx]
        chunk_results = []
        
        async with aiohttp.ClientSession() as session:
            for sample in chunk:
                if sample['id'] in state['completed_samples']:
                    continue
                
                sample_results = []
                for template_prompt in sample['template_prompts']:
                    result = await self.generate_single_image(
                        session,
                        sample,
                        template_prompt,
                        semaphore
                    )
                    sample_results.append(result)
                
                # Track sample completion
                if all(r['success'] for r in sample_results):
                    state['completed_samples'].append(sample['id'])
                else:
                    state['failed_samples'].append({
                        'sample_id': sample['id'],
                        'results': sample_results
                    })
                
                chunk_results.extend(sample_results)
                self.save_state(state)
                
        return chunk_results

    async def generate_all_images(self, chunk_size: int = 5):
        """Generate all images with resume capability and enhanced control"""
        try:
            # Create base directories
            os.makedirs(os.path.join(self.base_output_path, 'by_style'), exist_ok=True)
            os.makedirs(os.path.join(self.base_output_path, 'by_dataset'), exist_ok=True)
            
            # Load samples and state
            with open(self.input_path, 'r') as f:
                samples = json.load(f)
            
            state = self.load_state()
            start_idx = state['last_chunk_index']
            
            # Create semaphore for rate limiting
            semaphore = asyncio.Semaphore(2)
            
            # Initialize/reset control flags
            self.control.reset()
            
            # Process with progress tracking
            with Progress(
                SpinnerColumn(),
                *Progress.get_default_columns(),
                TimeElapsedColumn(),
                console=self.console
            ) as progress:
                total_remaining = len(samples) - start_idx
                task = progress.add_task("Generating images...", total=total_remaining)
                
                all_results = []
                for idx in range(start_idx, len(samples), chunk_size):
                    # Check for stop flag
                    if self.control.stop_flag:
                        self.console.print("[yellow]Processing stopped by user")
                        break
                        
                    # Check for pause flag
                    while self.control.pause_flag:
                        self.console.print("[yellow]Processing paused... waiting")
                        await asyncio.sleep(5)
                        
                    # Process chunk
                    chunk_results = await self.process_chunk(
                        samples, idx, chunk_size, state, semaphore
                    )
                    all_results.extend(chunk_results)
                    
                    # Update state and progress
                    state['last_chunk_index'] = idx + chunk_size
                    self.save_state(state)
                    
                    # Update progress bar
                    progress.update(task, advance=min(chunk_size, total_remaining - (idx - start_idx)))
                    
                    # Print chunk statistics
                    stats = self.stats.get_summary()
                    self.console.print(f"\nChunk {idx//chunk_size + 1} Statistics:")
                    for key, value in stats.items():
                        self.console.print(f"{key}: {value}")
                    
                    # Add delay between chunks
                    await asyncio.sleep(2)
            
            # Final report
            self.console.print("\n[green]Processing completed:")
            self.console.print(f"Completed samples: {len(state['completed_samples'])}")
            self.console.print(f"Failed samples: {len(state['failed_samples'])}")
            
            # Save final statistics
            final_stats = self.stats.get_summary()
            with open(os.path.join(self.base_output_path, 'processing_stats.json'), 'w') as f:
                json.dump(final_stats, f, indent=2)
            
            return all_results
            
        except Exception as e:
            self.console.print(f"[red]Error: {str(e)}")
            return []

async def main():
    """Main execution function with enhanced error handling"""
    try:
        # Get API key
        api_key = os.getenv("OPENAI_API_KEY")
        if not api_key:
            raise ValueError("OPENAI_API_KEY environment variable not set")
        
        # Initialize generator
        generator = RobustImageGenerator(api_key)
        
        # Process all samples
        await generator.generate_all_images(chunk_size=5)
        
    except KeyboardInterrupt:
        print("\nProcess interrupted by user")
    except Exception as e:
        print(f"Error in main execution: {str(e)}")
    finally:
        print("\nProcessing finished")

def run_script():
    """Entry point for script execution"""
    try:
        if asyncio.get_event_loop().is_running():
            # We're in a notebook with a running event loop
            asyncio.ensure_future(main())
        else:
            # We're in a script or notebook without running loop
            asyncio.run(main())
    except Exception as e:
        print(f"Error setting up async loop: {str(e)}")

# Run the script
if __name__ == "__main__":
    run_script()
# Out:
# ⠇ Generating images... -----------------------------------   0% -:--:-- 0:17:17
# Chunk 65 Statistics:
# duration: 0:17:17.589121----------------------   0% -:--:-- 0:17:17
# total_attempts: 80-----------------------------------   0% -:--:-- 0:17:17
# successful_downloads: 80---------------------------------   0% -:--:-- 0:17:17
# failed_downloads: 030m-----------------------------------   0% -:--:-- 0:17:17
# rate_limit_hits: 0-----------------------------------   0% -:--:-- 0:17:17
# connection_errors: 00m-----------------------------------   0% -:--:-- 0:17:17
# success_rate: 100.00%m-----------------------------------   0% -:--:-- 0:17:17
# Retry 1/3 after error: Cannot connect to host   6% -:--:-- 0:22:58
# oaidalleapiprodscus.blob.core.windows.net:443 ssl:default [An existing
# connection was forcibly closed by the remote host]
# Error processing wikipedia_496, minimalistic: Error code: 400 - {'error': :23:09
# {'code': 'content_policy_violation', 'message': 'Your request was rejected as a
# result of our safety system. Your prompt may contain text that is not allowed
# by our safety system.', 'param': None, 'type': 'invalid_request_error'}}
# Retry 1/3 after error: Cannot connect to host   6% -:--:-- 0:23:58
# oaidalleapiprodscus.blob.core.windows.net:443 ssl:default [An existing
# connection was forcibly closed by the remote host]
# Error processing wikipedia_496, retro: Error code: 400 - {'error': {'code':
# 'content_policy_violation', 'message': 'Your request was rejected as a result
# of our safety system. Your prompt may contain text that is not allowed by our
# safety system.', 'param': None, 'type': 'invalid_request_error'}}
# ⠋ Generating images... -- --------------------------------   6% -:--:-- 0:39:51
# Chunk 66 Statistics:
# duration: 0:39:51.332484--------------------------------   6% -:--:-- 0:39:51
# total_attempts: 17691m-- --------------------------------   6% -:--:-- 0:39:51
# successful_downloads: 176 --------------------------------   6% -:--:-- 0:39:51
# failed_downloads: 091m-- --------------------------------   6% -:--:-- 0:39:51
# rate_limit_hits: 0-- --------------------------------   6% -:--:-- 0:39:51
# connection_errors: 21m-- --------------------------------   6% -:--:-- 0:39:51
# success_rate: 100.00%m-- --------------------------------   6% -:--:-- 0:39:51
# ⠧ Generating images... ---- ------------------------------  12% -:--:-- 1:01:48
# Chunk 67 Statistics:
# duration: 1:01:48.738576 ------------------------------  12% -:--:-- 1:01:48
# total_attempts: 27691m---- ------------------------------  12% -:--:-- 1:01:48
# successful_downloads: 276- ------------------------------  12% -:--:-- 1:01:48
# failed_downloads: 091m---- ------------------------------  12% -:--:-- 1:01:48
# rate_limit_hits: 0---- ------------------------------  12% -:--:-- 1:01:48
# connection_errors: 21m---- ------------------------------  12% -:--:-- 1:01:48
# success_rate: 100.00%m---- ------------------------------  12% -:--:-- 1:01:48
# ⠼ Generating images... ------ ----------------------------  19% -:--:-- 1:22:41
# Chunk 68 Statistics:
# duration: 1:22:41.3080521m ----------------------------  19% -:--:-- 1:22:41
# total_attempts: 37691m------ ----------------------------  19% -:--:-- 1:22:41
# successful_downloads: 376--- ----------------------------  19% -:--:-- 1:22:41
# failed_downloads: 091m------ ----------------------------  19% -:--:-- 1:22:41
# rate_limit_hits: 0------ ----------------------------  19% -:--:-- 1:22:41
# connection_errors: 2 -------- --------------------------  25% -:--:-- 1:22:41
# success_rate: 100.00%m-------- --------------------------  25% -:--:-- 1:22:41
# ⠼ Generating images... -------- --------------------------  25% -:--:-- 1:44:27
# Chunk 69 Statistics:
# duration: 1:44:27.739861 --------------------------  25% -:--:-- 1:44:27
# total_attempts: 47691m-------- --------------------------  25% -:--:-- 1:44:27
# successful_downloads: 476----- --------------------------  25% -:--:-- 1:44:27
# failed_downloads: 0. ---------- ------------------------  31% -:--:-- 1:44:27
# rate_limit_hits: 0---------- ------------------------  31% -:--:-- 1:44:27
# connection_errors: 21m---------- ------------------------  31% -:--:-- 1:44:27
# success_rate: 100.00%m---------- ------------------------  31% -:--:-- 1:44:27
# Error processing asset_485, technical: Error code: 400 - {'error': {'code':
# 'content_policy_violation', 'message': 'Your request was rejected as a result
# of our safety system. Your prompt may contain text that is not allowed by our
# safety system.', 'param': None, 'type': 'invalid_request_error'}}
# ⠹ Generating images... ---------- ------------------------  31% -:--:-- 2:05:14
# Chunk 70 Statistics:
# duration: 2:05:14.745278m ------------------------  31% -:--:-- 2:05:14
# total_attempts: 57491m---------- ------------------------  31% -:--:-- 2:05:14
# successful_downloads: 574------- ------------------------  31% -:--:-- 2:05:14
# failed_downloads: 091m---------- ------------------------  31% -:--:-- 2:05:14
# rate_limit_hits: 0---------- ------------------------  31% -:--:-- 2:05:14
# connection_errors: 21m---------- ------------------------  31% -:--:-- 2:05:14
# success_rate: 100.00%m---------- ------------------------  31% -:--:-- 2:05:14
# Error processing asset_472, retro: Error code: 400 - {'error': {'code':
# 'content_policy_violation', 'message': 'Your request was rejected as a result
# of our safety system. Your prompt may contain text that is not allowed by our
# safety system.', 'param': None, 'type': 'invalid_request_error'}}
# ⠸ Generating images... ------------- ---------------------  38% -:--:-- 2:26:14
# Chunk 71 Statistics:
# duration: 2:26:14.775371 ---------------------  38% -:--:-- 2:26:14
# total_attempts: 67291m------------- ---------------------  38% -:--:-- 2:26:14
# successful_downloads: 672---------- ---------------------  38% -:--:-- 2:26:14
# failed_downloads: 091m------------- ---------------------  38% -:--:-- 2:26:14
# rate_limit_hits: 0------------- ---------------------  38% -:--:-- 2:26:14
# connection_errors: 21m------------- ---------------------  38% -:--:-- 2:26:14
# success_rate: 100.00%m------------- ---------------------  38% -:--:-- 2:26:14
# Error processing asset_164, geometric: Error code: 400 - {'error': {'code':
# 'content_policy_violation', 'message': 'Your request was rejected as a result
# of our safety system. Your prompt may contain text that is not allowed by our
# safety system.', 'param': None, 'type': 'invalid_request_error'}}
# Error processing asset_164, technical: Error code: 400 - {'error': {'code':
# 'content_policy_violation', 'message': 'Your request was rejected as a result
# of our safety system. Your prompt may contain text that is not allowed by our
# safety system.', 'param': None, 'type': 'invalid_request_error'}}
# ⠙ Generating images... --------------- -------------------  44% -:--:-- 2:46:26
# Chunk 72 Statistics:
# duration: 2:46:26.594628-- -------------------  44% -:--:-- 2:46:26
# total_attempts: 76891m--------------- -------------------  44% -:--:-- 2:46:26
# successful_downloads: 768------------ -------------------  44% -:--:-- 2:46:26
# failed_downloads: 091m--------------- -------------------  44% -:--:-- 2:46:26
# rate_limit_hits: 0--------------- -------------------  44% -:--:-- 2:46:26
# connection_errors: 21m--------------- -------------------  44% -:--:-- 2:46:26
# success_rate: 100.00%m--------------- -------------------  44% -:--:-- 2:46:26
# Error processing wikipedia_261, cartoon: Error code: 400 - {'error': {'code':
# 'content_policy_violation', 'message': 'Your request was rejected as a result
# of our safety system. Your prompt may contain text that is not allowed by our
# safety system.', 'param': None, 'type': 'invalid_request_error'}}
# Error processing wikipedia_261, artistic: Error code: 400 - {'error': {'code':
# 'content_policy_violation', 'message': 'Your request was rejected as a result
# of our safety system. Your prompt may contain text that is not allowed by our
# safety system.', 'param': None, 'type': 'invalid_request_error'}}
# Error processing wikipedia_261, minimalistic: Error code: 400 - {'error': :47:41
# {'code': 'content_policy_violation', 'message': 'Your request was rejected as a
# result of our safety system. Your prompt may contain text that is not allowed
# by our safety system.', 'param': None, 'type': 'invalid_request_error'}}
# Error processing wikipedia_261, digital art: Error code: 400 - {'error': 2:47:47
# {'code': 'content_policy_violation', 'message': 'Your request was rejected as a
# result of our safety system. Your prompt may contain text that is not allowed
# by our safety system.', 'param': None, 'type': 'invalid_request_error'}}
# Error processing wikipedia_261, 3d rendered: Error code: 400 - {'error': 2:47:58
# {'code': 'content_policy_violation', 'message': 'Your request was rejected as a
# result of our safety system. Your prompt may contain text that is not allowed
# by our safety system.', 'param': None, 'type': 'invalid_request_error'}}
# Error processing wikipedia_261, retro: Error code: 400 - {'error': {'code':
# 'content_policy_violation', 'message': 'Your request was rejected as a result
# of our safety system. Your prompt may contain text that is not allowed by our
# safety system.', 'param': None, 'type': 'invalid_request_error'}}
# Error processing wikipedia_261, technical: Error code: 400 - {'error': {'code':
# 'content_policy_violation', 'message': 'Your request was rejected as a result
# of our safety system. Your prompt may contain text that is not allowed by our
# safety system.', 'param': None, 'type': 'invalid_request_error'}}
# ⠼ Generating images... ----------------- -----------------  50% -:--:-- 3:05:38
# Chunk 73 Statistics:
# duration: 3:05:38.929935---- -----------------  50% -:--:-- 3:05:38
# total_attempts: 85491m----------------- -----------------  50% -:--:-- 3:05:38
# successful_downloads: 854-------------- -----------------  50% -:--:-- 3:05:38
# failed_downloads: 091m----------------- -----------------  50% -:--:-- 3:05:38
# rate_limit_hits: 0----------------- -----------------  50% -:--:-- 3:05:38
# connection_errors: 21m----------------- -----------------  50% -:--:-- 3:05:38
# success_rate: 100.00%m----------------- -----------------  50% -:--:-- 3:05:38
# ⠇ Generating images... ------------------- ---------------  56% -:--:-- 3:27:09
# Chunk 74 Statistics:
# duration: 3:27:09.639614------ ---------------  56% -:--:-- 3:27:09
# total_attempts: 95491m------------------- ---------------  56% -:--:-- 3:27:09
# successful_downloads: 954---------------- ---------------  56% -:--:-- 3:27:09
# failed_downloads: 091m------------------- ---------------  56% -:--:-- 3:27:09
# rate_limit_hits: 0------------------- ---------------  56% -:--:-- 3:27:09
# connection_errors: 21m------------------- ---------------  56% -:--:-- 3:27:09
# success_rate: 100.00%m------------------- ---------------  56% -:--:-- 3:27:09
# ⠦ Generating images... --------------------- -------------  62% -:--:-- 3:47:56
# Chunk 75 Statistics:
# duration: 3:47:56.741535-------- -------------  62% -:--:-- 3:47:56
# total_attempts: 10541m--------------------- -------------  62% -:--:-- 3:47:56
# successful_downloads: 1054----------------- -------------  62% -:--:-- 3:47:56
# failed_downloads: 091m--------------------- -------------  62% -:--:-- 3:47:56
# rate_limit_hits: 0--------------------- -------------  62% -:--:-- 3:47:56
# connection_errors: 21m--------------------- -------------  62% -:--:-- 3:47:56
# success_rate: 100.00%m--------------------- -------------  62% -:--:-- 3:47:56
# ⠼ Generating images... ------------------------ ----------  69% -:--:-- 4:08:48
# Chunk 76 Statistics:
# duration: 4:08:48.520965----------- ----------  69% -:--:-- 4:08:48
# total_attempts: 11541m------------------------ ----------  69% -:--:-- 4:08:48
# successful_downloads: 1154-------------------- ----------  69% -:--:-- 4:08:48
# failed_downloads: 091m------------------------ ----------  69% -:--:-- 4:08:48
# rate_limit_hits: 0------------------------ ----------  69% -:--:-- 4:08:48
# connection_errors: 21m------------------------ ----------  69% -:--:-- 4:08:48
# success_rate: 100.00%m------------------------ ----------  69% -:--:-- 4:08:48
# ⠦ Generating images... -------------------------- --------  75% -:--:-- 4:28:26
# Chunk 77 Statistics:
# duration: 4:28:26.396537------------- --------  75% -:--:-- 4:28:26
# total_attempts: 12541m-------------------------- --------  75% -:--:-- 4:28:26
# successful_downloads: 1254---------------------- --------  75% -:--:-- 4:28:26
# failed_downloads: 091m-------------------------- --------  75% -:--:-- 4:28:26
# rate_limit_hits: 0.. ---------------------------- ------  81% -:--:-- 4:28:26
# connection_errors: 21m---------------------------- ------  81% -:--:-- 4:28:26
# success_rate: 100.00%m---------------------------- ------  81% -:--:-- 4:28:26
# Retry 1/3 after error: Cannot connect to host  81% -:--:-- 4:29:15
# oaidalleapiprodscus.blob.core.windows.net:443 ssl:default [An existing
# connection was forcibly closed by the remote host]
# Error processing wikipedia_065, minimalistic: Error code: 400 - {'error': :45:08
# {'code': 'content_policy_violation', 'message': 'Your request was rejected as a
# result of our safety system. Your prompt may contain text that is not allowed
# by our safety system.', 'param': None, 'type': 'invalid_request_error'}}
# Error processing wikipedia_065, retro: Error code: 400 - {'error': {'code':
# 'content_policy_violation', 'message': 'Your request was rejected as a result
# of our safety system. Your prompt may contain text that is not allowed by our
# safety system.', 'param': None, 'type': 'invalid_request_error'}}
# Error processing wikipedia_065, technical: Error code: 400 - {'error': {'code':
# 'content_policy_violation', 'message': 'Your request was rejected as a result
# of our safety system. Your prompt may contain text that is not allowed by our
# safety system.', 'param': None, 'type': 'invalid_request_error'}}
# ⠧ Generating images... ---------------------------- ------  81% -:--:-- 4:51:14
# Chunk 78 Statistics:
# duration: 4:51:14.457470--------------- ------  81% -:--:-- 4:51:14
# total_attempts: 13481m---------------------------- ------  81% -:--:-- 4:51:14
# successful_downloads: 1348------------------------ ------  81% -:--:-- 4:51:14
# failed_downloads: 091m---------------------------- ------  81% -:--:-- 4:51:14
# rate_limit_hits: 0---------------------------- ------  81% -:--:-- 4:51:14
# connection_errors: 31m---------------------------- ------  81% -:--:-- 4:51:14
# success_rate: 100.00%m---------------------------- ------  81% -:--:-- 4:51:14
# ⠴ Generating images... ------------------------------ ----  88% -:--:-- 5:12:06
# Chunk 79 Statistics:
# duration: 5:12:07.028413----------------- ----  88% -:--:-- 5:12:06
# total_attempts: 14481m------------------------------ ----  88% -:--:-- 5:12:06
# successful_downloads: 1448-------------------------- ----  88% -:--:-- 5:12:06
# failed_downloads: 091m------------------------------ ----  88% -:--:-- 5:12:06
# rate_limit_hits: 0------------------------------ ----  88% -:--:-- 5:12:06
# connection_errors: 31m------------------------------ ----  88% -:--:-- 5:12:06
# success_rate: 100.00%m------------------------------ ----  88% -:--:-- 5:12:06
# Error processing wikipedia_259, realistic: Error code: 400 - {'error': {'code':
# 'content_policy_violation', 'message': 'Your request was rejected as a result
# of our safety system. Your prompt may contain text that is not allowed by our
# safety system.', 'param': None, 'type': 'invalid_request_error'}}
# Error processing wikipedia_259, minimalistic: Error code: 400 - {'error': :17:02
# {'code': 'content_policy_violation', 'message': 'Your request was rejected as a
# result of our safety system. Your prompt may contain text that is not allowed
# by our safety system.', 'param': None, 'type': 'invalid_request_error'}}
# ⠸ Generating images... -------------------------------- --  94% -:--:-- 5:30:46
# Chunk 80 Statistics:
# duration: 5:30:46.977693------------------- --  94% -:--:-- 5:30:46
# total_attempts: 15441m-------------------------------- --  94% -:--:-- 5:30:46
# successful_downloads: 1544---------------------------- --  94% -:--:-- 5:30:46
# failed_downloads: 091m-------------------------------- --  94% -:--:-- 5:30:46
# rate_limit_hits: 0-------------------------------- --  94% -:--:-- 5:30:46
# connection_errors: 3-------------------------------- 100% 0:00:00 5:30:46-- 5:30:46
# success_rate: 100.00%--------------------------- 100% 0:00:00 5:30:46
#   Generating images... ----------------------------------- 100% 0:00:00 5:30:46
#
# Processing completed:
# Completed samples: 362
# Failed samples: 39
#
# Processing finished
